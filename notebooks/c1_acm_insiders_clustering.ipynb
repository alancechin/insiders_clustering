# %% [markdown]
# # PA005: High Value Customer Identification
#
# Na cor preta: o que foi desenvolvido no ciclo.
#
#
# Na cor vermelha: o que não foi desenvolvido no ciclo ou que foi feito o mínimo necessário para gerar um resultado inicial no projeto.

# %% [markdown]
# # 0.0 Imports

# %%
# Biblioteca para manipulação dos dataframes
import pandas   as pd 
# Biblioteca para trabalhar com vetores e arrays
import numpy    as np

# Bibliotecas para trabalhar com Gráficos
import seaborn  as sns

from matplotlib import pyplot  as plt 
from plotly import express as px 
# Biblioteca para configurar layout tela Jupyter
from IPython.core.display import HTML

# Biblioteca para alterar nome das colunas de Kamel Case para Snake Case
import inflection

# Biblioteca para implementar e avaliar algoritmos 
from sklearn import cluster as ct
from sklearn import metrics as mt
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

import plotly.graph_objs as go

# %% [markdown]
# ## 0.1 Helper functions

# %%
def jupyter_settings():
    # %matplotlib inline
    #%pylab inline
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [20, 10]
    plt.rcParams['font.size'] = 10
    display( HTML( '<style>.container { width:97% !important; }</style>') )
    pd.options.display.max_columns = 50
    pd.options.display.max_rows = 50
    pd.set_option( 'display.expand_frame_repr', False )
    sns.set()
    pd.set_option('display.float_format', lambda x: '%.3f' % x)
    
    return None

jupyter_settings()
# Out:
# <style>.container { width:97% !important; }</style>

# %% [markdown]
# ## 0.2 Load Dataset

# %%
# load data
df_raw = pd.read_csv('C:/Users/alanc/Documents/repos/insiders_clustering/data/raw/ecommerce.csv', encoding = 'unicode_escape' )

# drop extra column
df_raw.drop(columns = ['Unnamed: 8'], inplace = True)

# %%
df_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity InvoiceDate  UnitPrice  CustomerID         Country
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6   29-Nov-16      2.550   17850.000  United Kingdom
# 1    536365     71053                  WHITE METAL LANTERN         6   29-Nov-16      3.390   17850.000  United Kingdom
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8   29-Nov-16      2.750   17850.000  United Kingdom
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6   29-Nov-16      3.390   17850.000  United Kingdom
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6   29-Nov-16      3.390   17850.000  United Kingdom

# %% [markdown]
# #  1.0 Descrição dos dados

# %%
### Cópia do dataframe em início de sessão 
### OBJETIVO: Caso seja realizado alguma instrução errada sob os dados trabalhados, poder ter um ponto de backup.

df1 = df_raw.copy()

# %% [markdown]
# ## 1.1. Rename Columns
#
# Ter o nome das colunas de maneira mais intuitiva para trabalhar com ciência de dados

# %%
df1.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
cols_old = ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
            'UnitPrice', 'CustomerID', 'Country']

## Utiliza função lambda para encapsular a função que transforma para snake_case os atributos
snakecase = lambda x: inflection.underscore( x )

## Map - Mapeia cada valor dentro da estrutura de dado passada e aplica a função snakecase
cols_new = list( map( snakecase, cols_old ) )

## rename 
df1.columns = cols_new

# %%
df1.columns
# Out:
# Index(['invoice_no', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'customer_id', 'country'],
#       dtype='object')

# %% [markdown]
# ## 1.2 Columns Meanings
#
# Objetivo é compreender o significado de cada coluna

# %% [markdown]
# - **invoice_no:** identificador único de cada transação;
#
#
# - **stock_code:** código do item;
#
#
# - **description:** nome do item;
#
#
# - **quantity:** quantidade de cada item comprado por transação;
#
#
# - **invoice_data:** data em que a transação ocorreu;
#
#
# - **unit_price:** preço unitário do produto;
#
#
# - **customer_id:** identificador único do cliente;
#
#
# - **country:** país que o cliente reside.

# %% [markdown]
# ## 1.3. Data Dimensions
#
# Analisar a dimensão dos dados a serem trabalhados

# %%
print(f"Número de linhas: {df1.shape[0]}")
print(f"Número de colunas: {df1.shape[1]}")
# Out:
# Número de linhas: 541909
# Número de colunas: 8

# %% [markdown]
# ## 1.4. Data Types
#
# Verificar se os tipos de dados correspondem corretamente a informação que as colunas estão apresentando

# %%
df1.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %% [markdown]
# ## 1.5. Check NA
#
# Verificar a existência de valores nulos

# %%
df1.isna().sum()
# Out:
# invoice_no           0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64

# %% [markdown]
# ## <font color = 'red'> 1.6.  Fillout NA </font>
#
# Tratar os valores nulos

# %%
## Tratar da maneira mais simples primeiramente -> remover na
df1.dropna( subset = ['description','customer_id'], inplace = True )

print("Dados Removidos: {:.2f}%".format( (1 - (df1.shape[0]/df_raw.shape[0]) )*100  ) )
# Out:
# Dados Removidos: 24.93%

# %%
df1.isna().sum()
# Out:
# invoice_no      0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# customer_id     0
# country         0
# dtype: int64

# %% [markdown]
# ## 1.7. Change Data Types

# %%
df1.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %%
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity invoice_date  unit_price  customer_id         country
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6    29-Nov-16       2.550    17850.000  United Kingdom
# 1     536365      71053                  WHITE METAL LANTERN         6    29-Nov-16       3.390    17850.000  United Kingdom
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8    29-Nov-16       2.750    17850.000  United Kingdom
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6    29-Nov-16       3.390    17850.000  United Kingdom
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6    29-Nov-16       3.390    17850.000  United Kingdom

# %%
# arrumar coluna para ficar com tipo de dado de date 
df1['invoice_date'] = pd.to_datetime(df1['invoice_date'], format = '%d-%b-%y')

# passar coluna de float64 -> int64, não tem necessidade de ser float 
df1['customer_id'] = df1['customer_id'].astype('int64')

# %%
df1.dtypes
# Out:
# invoice_no              object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id              int64
# country                 object
# dtype: object

# %%
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity invoice_date  unit_price  customer_id         country
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6   2016-11-29       2.550        17850  United Kingdom
# 1     536365      71053                  WHITE METAL LANTERN         6   2016-11-29       3.390        17850  United Kingdom
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8   2016-11-29       2.750        17850  United Kingdom
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6   2016-11-29       3.390        17850  United Kingdom
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6   2016-11-29       3.390        17850  United Kingdom

# %% [markdown]
# ## <font color = 'red'> 1.8. Descriptive Statistical </font>
#
#
# Resumo Geral dos dados com o objetivo de compreender comportamento , outliers e anormalidades nos valores dos atributos.

# %% [markdown]
# ### 1.8.1. Numerical Attributes

# %% [markdown]
# ### 1.8.2. Categorical Attributes

# %% [markdown]
# #  2.0 Feature Engineering
#
# O objetivo é criar/ajustar atributos por meio dos já existentes os quais possam ser relevantes para explicar o fenômeno de análise.

# %%
### Cópia do dataframe em início de sessão 
### OBJETIVO: Caso seja realizado alguma instrução errada sob os dados trabalhados, poder ter um ponto de backup.

df2 = df1.copy()

# %% [markdown]
# ## 2.1. Creation Features
#
# - Criar features RFM (Recency, Frequency, Monetary);

# %%
# Estratégia

# 0. Arrumar granularidade (menor nível de detalhamento dos dados) do conjunto de dados em um dataframe novo; 
# 1. Calcular features que desejo para os clientes (Recency, Frequency, Monetary)
#     1.1. Monetary: gross_revenue = quantity * unit_price para cada linha da base atual
#     1.2. Faturamento (gross_revenue_total) p/ cliente = Agrupar clientes da base e somar o revenue durante todo o período disponível na base

#     1.3. Recency: agrupo datas de compra por cliente e filtro a mais recente 
#     1.4. Tempo em dias desde a última compra do cliente = Data mais recente no histórico e subtrair da data de compra mais recente de cada cliente

#     1.5. Frequency: Agrupar clientes da base e somar a quantidade total de compras durante todo o período disponível na base 

df2.head()
# Out:
#   invoice_no stock_code                          description  quantity invoice_date  unit_price  customer_id         country
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6   2016-11-29       2.550        17850  United Kingdom
# 1     536365      71053                  WHITE METAL LANTERN         6   2016-11-29       3.390        17850  United Kingdom
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8   2016-11-29       2.750        17850  United Kingdom
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6   2016-11-29       3.390        17850  United Kingdom
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6   2016-11-29       3.390        17850  United Kingdom

# %% [markdown]
# - Conjunto de dados originalmente é detalhado em produtos por transação;
#
#
# - A chave primária de cada amostra/obs. (granularidade) do conjunto de dados é o conjunto ( invoice_no (transação) | stock_code (produtos) )  pois é o que varia;
#
#
# - Transações diferentes no mesmo dia podem ter clientes iguais;
#
#
# - O objetivo é ajustar a granularidade da tabela por cliente, colocando as features que me interessam para realizar a clusterização.

# %%
## MONETARY ------------------------------------------------

# 1.1 

df2['gross_revenue'] = df2['quantity'] * df2['unit_price']

# 0 e 1.2

df_ref = df2[['gross_revenue', 'customer_id']].groupby(by = 'customer_id').sum().reset_index()

## RECENCY ------------------------------------------------

# 1.3 

df_recency = df2[['customer_id','invoice_date']].groupby(by = 'customer_id').max().reset_index()

#1.4

df_recency['recency_days'] = (df2['invoice_date'].max() - df_recency['invoice_date']).dt.days

# Preparar para juntar com dados referencia

df_recency.drop(columns = 'invoice_date', inplace = True)

# unir com dados referencia 

df_ref = pd.merge(df_ref, df_recency, on = 'customer_id', how = 'left')

## FREQUENCY ------------------------------------------------

#1.5

df_frequency = df2[['customer_id','invoice_no']].groupby(by = 'customer_id').nunique().reset_index()

# unir frequencia com conjunto de dados referencia 

df_ref = pd.merge(df_ref, df_frequency, on = 'customer_id', how = 'left')

# renomeando as colunas

df_ref.columns = ['customer_id','gross_revenue_total','recency_days','frequency_total']
df_ref
# Out:
#       customer_id  gross_revenue_total  recency_days  frequency_total
# 0           12346                0.000           325                2
# 1           12347             4310.000             2                7
# 2           12348             1797.240            75                4
# 3           12349             1757.550            18                1
# 4           12350              334.400           310                1
# ...           ...                  ...           ...              ...
# 4367        18280              180.600           277                1
# 4368        18281               80.820           180                1
# 4369        18282              176.600             7                3
# 4370        18283             2094.880             3               16
# 4371        18287             1837.280            42                3
#
# [4372 rows x 4 columns]

# %% [markdown]
# - Conjunto de dados desenvolvido já é suficiente para aplicar clusterização e analisar resultado do ciclo 0.

# %%
## Pesquisando clientes que não possuem histórico de faturamento na empresa (gross_revenue = 0)

up_zero = df2['unit_price'] == 0 
q_zero = df2['quantity'] == 0

df2.loc[ up_zero | q_zero  , :]
# Out:
#        invoice_no stock_code                          description  quantity invoice_date  unit_price  customer_id         country  gross_revenue
# 9302       537197      22841         ROUND CAKE TIN VINTAGE GREEN         1   2016-12-03       0.000        12647         Germany          0.000
# 33576      539263      22580         ADVENT CALENDAR GINGHAM SACK         4   2016-12-14       0.000        16560  United Kingdom          0.000
# 40089      539722      22423             REGENCY CAKESTAND 3 TIER        10   2016-12-19       0.000        14911            EIRE          0.000
# 47068      540372      22090              PAPER BUNTING RETROSPOT        24   2017-01-04       0.000        13081  United Kingdom          0.000
# 47070      540372      22553               PLASTERS IN TIN SKULLS        24   2017-01-04       0.000        13081  United Kingdom          0.000
# 56674      541109      22168        ORGANISER WOOD ANTIQUE WHITE          1   2017-01-11       0.000        15107  United Kingdom          0.000
# 86789      543599     84535B         FAIRY CAKES NOTEBOOK A6 SIZE        16   2017-02-08       0.000        17560  United Kingdom          0.000
# 130188     547417      22062  CERAMIC BOWL WITH LOVE HEART DESIGN        36   2017-03-21       0.000        13239  United Kingdom          0.000
# 139453     548318      22055   MINI CAKE STAND  HANGING STRAWBERY         5   2017-03-28       0.000        13113  United Kingdom          0.000
# 145208     548871      22162          HEART GARLAND RUSTIC PADDED         2   2017-04-02       0.000        14410  United Kingdom          0.000
# 157042     550188      22636   CHILDS BREAKFAST SET CIRCUS PARADE         1   2017-04-12       0.000        12457     Switzerland          0.000
# 187613     553000      47566                        PARTY BUNTING         4   2017-05-10       0.000        17667  United Kingdom          0.000
# 198383     554037      22619            SET OF 6 SOLDIER SKITTLES        80   2017-05-18       0.000        12415       Australia          0.000
# 279324     561284      22167           OVAL WALL MIRROR DIAMANTE          1   2017-07-24       0.000        16818  United Kingdom          0.000
# 282912     561669      22960             JAM MAKING SET WITH JARS        11   2017-07-26       0.000        12507           Spain          0.000
# 285657     561916          M                               Manual         1   2017-07-30       0.000        15581  United Kingdom          0.000
# 298054     562973      23157           SET OF 6 NATIVITY MAGNETS        240   2017-08-09       0.000        14911            EIRE          0.000
# 314745     564651      23270     SET OF 2 CERAMIC PAINTED HEARTS         96   2017-08-24       0.000        14646     Netherlands          0.000
# 314746     564651      23268  SET OF 2 CERAMIC CHRISTMAS REINDEER       192   2017-08-24       0.000        14646     Netherlands          0.000
# 314747     564651      22955             36 FOIL STAR CAKE CASES        144   2017-08-24       0.000        14646     Netherlands          0.000
# 314748     564651      21786                   POLKADOT RAIN HAT        144   2017-08-24       0.000        14646     Netherlands          0.000
# 358655     568158       PADS           PADS TO MATCH ALL CUSHIONS         1   2017-09-23       0.000        16133  United Kingdom          0.000
# 361825     568384          M                               Manual         1   2017-09-25       0.000        12748  United Kingdom          0.000
# 379913     569716      22778                   GLASS CLOCHE SMALL         2   2017-10-04       0.000        15804  United Kingdom          0.000
# 395529     571035          M                               Manual         1   2017-10-11       0.000        12446             RSA          0.000
# 420404     572893      21208          PASTEL COLOUR HONEYCOMB FAN         5   2017-10-24       0.000        18059  United Kingdom          0.000
# 436428     574138      23234        BISCUIT TIN VINTAGE CHRISTMAS       216   2017-11-01       0.000        12415       Australia          0.000
# 436597     574175      22065       CHRISTMAS PUDDING TRINKET POT         12   2017-11-01       0.000        14110  United Kingdom          0.000
# 436961     574252          M                               Manual         1   2017-11-01       0.000        12437          France          0.000
# 439361     574469      22385            JUMBO BAG SPACEBOY DESIGN        12   2017-11-02       0.000        12431       Australia          0.000
# 446125     574879      22625                   RED KITCHEN SCALES         2   2017-11-05       0.000        13014  United Kingdom          0.000
# 446793     574920      22899         CHILDREN'S APRON DOLLY GIRL          1   2017-11-05       0.000        13985  United Kingdom          0.000
# 446794     574920      23480       MINI LIGHTS WOODLAND MUSHROOMS         1   2017-11-05       0.000        13985  United Kingdom          0.000
# 454463     575579      22437        SET OF 9 BLACK SKULL BALLOONS        20   2017-11-08       0.000        13081  United Kingdom          0.000
# 454464     575579      22089        PAPER BUNTING VINTAGE PAISLEY        24   2017-11-08       0.000        13081  United Kingdom          0.000
# 479079     577129      22464          HANGING METAL HEART LANTERN         4   2017-11-15       0.000        15602  United Kingdom          0.000
# 479546     577168          M                               Manual         1   2017-11-16       0.000        12603         Germany          0.000
# 480649     577314      23407       SET OF 2 TRAYS HOME SWEET HOME         2   2017-11-16       0.000        12444          Norway          0.000
# 485985     577696          M                               Manual         1   2017-11-19       0.000        16406  United Kingdom          0.000
# 502122     578841      84826       ASSTD DESIGN 3D PAPER STICKERS     12540   2017-11-23       0.000        13256  United Kingdom          0.000

# %% [markdown]
# # <font color = 'red'>  3.0 Filtragem de Variáveis </font>

# %%
### Cópia do dataframe em início de sessão 
### OBJETIVO: Caso seja realizado alguma instrução errada sob os dados trabalhados, poder ter um ponto de backup.

df3 = df_ref.copy()

# %% [markdown]
# # <font color = 'red'>  4.0 EDA (Exploratory Data Analysis) </font>

# %%
### Cópia do dataframe em início de sessão 
### OBJETIVO: Caso seja realizado alguma instrução errada sob os dados trabalhados, poder ter um ponto de backup.

df4 = df3.copy()

# %% [markdown]
# # <font color = 'red'>  5.0 Data Preparation </font>

# %%
### Cópia do dataframe em início de sessão 
### OBJETIVO: Caso seja realizado alguma instrução errada sob os dados trabalhados, poder ter um ponto de backup.

df5 = df4.copy()

# %% [markdown]
# # <font color = 'red'>  6.0 Feature Selection </font>

# %%
### Cópia do dataframe em início de sessão 
### OBJETIVO: Caso seja realizado alguma instrução errada sob os dados trabalhados, poder ter um ponto de backup.

df6 = df5.copy()

# %% [markdown]
# # 7.0 Hyperparameter Fine-Tuning
#
# Variar os valores de clusters e avaliar qualidade do agrupamento

# %%
### Cópia do dataframe em início de sessão 
### OBJETIVO: Caso seja realizado alguma instrução errada sob os dados trabalhados, poder ter um ponto de backup.

df7 = df6.copy()

X = df7.drop(columns = 'customer_id')

# %%
clusters = list(np.arange(2,10,1))

# %% [markdown]
# ## 7.1. Within-Cluster Sum of Square (WSS)

# %%
wss = []

for k in clusters:
    
    # model definition 
    
    kmeans = ct.KMeans(init = 'random', n_clusters = k, n_init = 10, random_state = 42)
    
    # model fit 
    
    kmeans.fit( X )
    
    # performance 
    wss.append(kmeans.inertia_)
    
    print(f"{k} cluster: {kmeans.inertia_}")
# Out:
# 2 cluster: 100161464120.90073
# 3 cluster: 52830442008.00699
# 4 cluster: 39986557693.70812
# 5 cluster: 22956286930.93181
# 6 cluster: 19974463394.76878
# 7 cluster: 9875686466.019762
# 8 cluster: 8379833854.128237
# 9 cluster: 7662899084.268939

# %%
## Visualização performance(WSS) x nº cluster passados para algoritmo

fig, ax1 = plt.subplots(figsize = (10,5))

ax1.plot(clusters, wss, marker = 'o');

plt.xlabel("Nº Clusters");
plt.ylabel("WSS");

# %%
## Utilizando a biblioteca yellowbrick

k_means = KElbowVisualizer( ct.KMeans(init = 'random', n_clusters = k, n_init = 10, random_state = 42), k = clusters, timings = False );
k_means.fit( X );
k_means.show();

# %% [markdown]
# - Pela métrica WSS deveria escolher k = 3 , pois é a quantidade de cluster que faz com que a soma das distâncias dos centroídes de cada cluster com cada ponto ao quadrado resulte em um valor com considerável redução com relação a soma das distâncias dos cluster adjacentes.

# %% [markdown]
# - Obviamente assumindo cluster maiores que 3 , o somatório das distâncias será menor pois irá obrigar o algoritmo a criar um novo centroíde, porém a redução de distâncias de cada ponto para o centroíde não é significativa ao ponto de justificar aumentar o número de clusters.

# %% [markdown]
# - Se a curva (elbow method) fosse mais suave, significa que a distribuição dos dados no espaço de features está bastante sobreposta (não há clusters naturais formados), não sendo possível a realização de agrupamentos consistentes. -> nesse caso, deve-se ajustar novo espaço de features.

# %% [markdown]
# ## 7.2. Silhouette Score (SS)

# %%
ss = []

for k in clusters:
    
    # model definition 
    
    kmeans = ct.KMeans(init = 'random', n_clusters = k, n_init = 10, random_state = 42)
    
    # model fit 
    
    kmeans.fit( X )
    
    # performance 
    ss_avg = mt.silhouette_score(X, kmeans.labels_)
    ss.append( ss_avg )
    
    print(f"{k} cluster: {ss_avg}")
# Out:
# 2 cluster: 0.9853353207868569
# 3 cluster: 0.9494677566681544
# 4 cluster: 0.8149170379682747
# 5 cluster: 0.7734960328917805
# 6 cluster: 0.7061828777437418
# 7 cluster: 0.7073502982056901
# 8 cluster: 0.6747272846309617
# 9 cluster: 0.6312363352127518

# %%
## Visualização performance(Silhouette Score Mean) x nº cluster passados para algoritmo

fig, ax1 = plt.subplots(figsize = (8,5))

ax1.plot(clusters, ss, marker = 'o');

plt.xlabel("Nº Clusters");
plt.ylabel("Silhouette Score");

# %%
## Utilizando a biblioteca yellowbrick

k_means = KElbowVisualizer( ct.KMeans(init = 'random', n_clusters = k, n_init = 10, random_state = 42), k = clusters, metric = 'silhouette', timings = False );
k_means.fit( X );
k_means.show();

# %% [markdown]
# **Conclusão:**
#
# - Ir para a produção treinando o modelo para encontrar 2 ou 3 clusters é o mais ideal dado o espaço de features disponível.

# %% [markdown]
# #   8.0 Model Training

# %% [markdown]
# ## 8.1. K-means

# %%
# model definition 
k = 3
rs = 42

kmeans = ct.KMeans( n_clusters= k, 
                    init='random', 
                    n_init=10, 
                    max_iter=300,
                    random_state=rs )

# model fit 
kmeans.fit( X )

# clustering
labels = kmeans.labels_

# %%
## WSS (Within-Cluster Sum of Square)
print("WSS: {}".format(kmeans.inertia_))

## SS (Silhouette Score)
print("SS: {}".format( mt.silhouette_score( X, labels ) ) )
# Out:
# WSS: 52830442008.00699
# SS: 0.9494677566681544

# %% [markdown]
# #  9.0 Cluster Analysis

# %% [markdown]
# ## 9.1. Visualization Inspection
#
# Visualização dos cluster até 3 dimensões, se maior que 3, usar técnica de redução de dimensionalidade

# %%
df9 = df7.copy()
df9['cluster'] = labels
df9.head()
# Out:
#    customer_id  gross_revenue_total  recency_days  frequency_total  cluster
# 0        12346                0.000           325                2        2
# 1        12347             4310.000             2                7        2
# 2        12348             1797.240            75                4        2
# 3        12349             1757.550            18                1        2
# 4        12350              334.400           310                1        2

# %%
# fig = px.scatter_3d(df9, x = 'recency_days', y = 'frequency_total', z = 'gross_revenue_total', color = 'cluster')
# fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 fig = px.scatter_3d(df9, x = 'recency_days', y = 'frequency_total', z = 'gross_revenue_total', color = 'cluster')
#       2 fig.show()
#
# File ~\anaconda3\envs\insiders_clustering\lib\site-packages\plotly\express\_chart_types.py:776, in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, template, width, height)
#     730 def scatter_3d(
#     731     data_frame=None,
#     732     x=None,
#    (...)
#     770     height=None,
#     771 ) -> go.Figure:
#     772     """
#     773     In a 3D scatter plot, each row of `data_frame` is represented by a
#     774     symbol mark in 3D space.
#     775     """
# --> 776     return make_figure(args=locals(), constructor=go.Scatter3d)
#
# File ~\anaconda3\envs\insiders_clustering\lib\site-packages\plotly\express\_core.py:1988, in make_figure(args, constructor, trace_patch, layout_patch)
#    1986 trace_patch = trace_patch or {}
#    1987 layout_patch = layout_patch or {}
# -> 1988 apply_default_cascade(args)
#    1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#
# File ~\anaconda3\envs\insiders_clustering\lib\site-packages\plotly\express\_core.py:928, in apply_default_cascade(args)
#     923 # if colors not set explicitly or in px.defaults, defer to a template
#     924 # if the template doesn't have one, we set some final fallback defaults
#     925 if "color_continuous_scale" in args:
#     926     if (
#     927         args["color_continuous_scale"] is None
# --> 928         and args["template"].layout.colorscale.sequential
#     929     ):
#     930         args["color_continuous_scale"] = [
#     931             x[1] for x in args["template"].layout.colorscale.sequential
#     932         ]
#     933     if args["color_continuous_scale"] is None:
#
# File ~\anaconda3\envs\insiders_clustering\lib\site-packages\plotly\graph_objs\layout\_template.py:231, in Template.layout(self)
#     216 @property
#     217 def layout(self):
#     218     """
#     219     The 'layout' property is an instance of Layout
#     220     that may be specified as:
#    (...)
#     229     plotly.graph_objs.layout.template.Layout
#     230     """
# --> 231     return self["layout"]
#
# File ~\anaconda3\envs\insiders_clustering\lib\site-packages\plotly\basedatatypes.py:4708, in BasePlotlyType.__getitem__(self, prop)
#    4703 if prop not in self._valid_props:
#    4704     self._raise_on_invalid_property_error(_error_to_raise=PlotlyKeyError)(
#    4705         prop
#    4706     )
# -> 4708 validator = self._get_validator(prop)
#    4710 if isinstance(validator, CompoundValidator):
#    4711     if self._compound_props.get(prop, None) is None:
#    4712         # Init compound objects
#
# File ~\anaconda3\envs\insiders_clustering\lib\site-packages\plotly\basedatatypes.py:4329, in BasePlotlyType._get_validator(self, prop)
#    4326 def _get_validator(self, prop):
#    4327     from .validator_cache import ValidatorCache
# -> 4329     return ValidatorCache.get_validator(self._path_str, prop)
#
# File ~\anaconda3\envs\insiders_clustering\lib\site-packages\plotly\validator_cache.py:28, in ValidatorCache.get_validator(parent_path, prop_name)
#      26         lookup_name = lookup_name or prop_name
#      27         class_name = lookup_name.title() + "Validator"
# ---> 28         validator = getattr(
#      29             importlib.import_module("plotly.validators." + parent_path),
#      30             class_name,
#      31         )(plotly_name=prop_name)
#      32     ValidatorCache._cache[key] = validator
#      34 return ValidatorCache._cache[key]
#
# AttributeError: module 'plotly.validators.layout.template' has no attribute 'LayoutValidator'

# %%
fig = go.Figure(data=[go.Scatter3d(x=df9['recency_days'], y=df9['frequency_total'], z=df9['gross_revenue_total'],
                                   mode='markers', marker=dict(size=12,color=df9['cluster'],colorscale='Viridis', opacity=0.8))])
fig.show()
# Out:
# <div>                            <div id="0dbd740c-41ea-4297-9f7a-8e9537be5b2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0dbd740c-41ea-4297-9f7a-8e9537be5b2f")) {                    Plotly.newPlot(                        "0dbd740c-41ea-4297-9f7a-8e9537be5b2f",                        [{"marker":{"color":[2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,0,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1,2,2,2,1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1,2,2,2,1,2,2,2,2,2,2,2,1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1,2,2,2,2,2,2,2,2,2,2,1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1,2,2,2,2,1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,0,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,0,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2 ...

# %%
## Silhouette Analysis

fig, ax1 = plt.subplots(figsize = (12,12))

kmeans = ct.KMeans( n_clusters= k,init='random', n_init=10, max_iter=300,random_state=rs )

visualizer = SilhouetteVisualizer(kmeans, colors = 'yellowbrick', ax = ax1)
visualizer.fit( X ) 
visualizer.finalize()

# %% [markdown]
# - Cluster 1 e 0 possuem clientes (amostras) com coeficiente de silhueta menor que 0, o que significa que essas amostras não percentem ao cluster que lhe foi atribuído.

# %% [markdown]
# ## 9.2. Cluster Profile

# %%
## Number of customer 

df_cluster = df9[['customer_id','cluster']].groupby(by = 'cluster').count().reset_index()
df_cluster['perc'] = 100 * (df_cluster['customer_id'] / df_cluster['customer_id'].sum())


## Avg gross_revenue_total
df_reve = df9[['gross_revenue_total','cluster']].groupby(by = 'cluster').mean().reset_index()

## Avg recency_days 
df_rece = df9[['recency_days','cluster']].groupby(by = 'cluster').mean().reset_index()

## Avg frequency_total
df_freq = df9[['frequency_total','cluster']].groupby(by = 'cluster').mean().reset_index()

## join tables
df_c_profile = df_cluster.merge(df_reve, on = 'cluster', how = 'left').merge(df_rece, on = 'cluster', how = 'left').merge(df_freq, on = 'cluster', how = 'left')

## rename columns 
df_c_profile.columns = ['cluster', 'n_customer', 'perc_customer', 'mean_revenue_total' , 'mean_recency_days', 'mean_frequency_total']
df_c_profile
# Out:
#    cluster  n_customer  perc_customer  mean_revenue_total  mean_recency_days  mean_frequency_total
# 0        0           6          0.137          182181.982              7.167                89.000
# 1        1          31          0.709           40543.518             13.290                53.290
# 2        2        4335         99.154            1372.578             92.258                 4.615

# %% [markdown]
# **Relatório:**
#
# ### CLUSTER 0: (Candidato à Insiders)
#
#         - Quantidade de clientes: 6 (0,14%)
#         - Média de faturamento total gerado: US 182.181,9
#         - Média da recência: 7,167 dias
#         - Média de transações no período total: 89
#
# ### CLUSTER 1:
#
#         - Quantidade de clientes: 31 (0,71%)
#         - Média de faturamento total gerado: US 40.543,5
#         - Média da recência: 13,3 dias
#         - Média de transações no período total: 53,29
#
# ### CLUSTER 2:
#
#         - Quantidade de clientes: 4.335 (99,15%)
#         - Média de faturamento total gerado: US 1.372,6
#         - Média da recência: 92,25 dias
#         - Média de transações no período total: 4,6

# %% [markdown]
# **Análise:**
#
# - Quantidade de amostras em cada cluster muito desequilibrada

# %% [markdown]
# # <font color = 'red'>  10.0 Deploy to production </font>
